# %% [markdown]
# <a href="https://colab.research.google.com/github/FranciscoGonzalezG957/Deteccion_colores/blob/main/Creacion_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Crear las carpetas para subir las imagenes
# !mkdir Manzana_roja
# !mkdir Platano
# !mkdir Mandarina
# !mkdir Fruta_NO_detectada

# %%
#Entrar en cada carpeta y descomprimir el archivo zip
# %cd Manzana_roja
# !unzip Manzana_roja.zip
# %cd ..

# %cd Mandarina
# !unzip Mandarina.zip
# %cd ..

# %cd Platano
# !unzip Platano.zip
# %cd ..

# %cd Fruta_NO_detectada
# !unzip Fruta_NO_detectada.zip
# %cd ..
# Out:
# /content/Manzana_roja
# Archive:  Manzana_roja.zip
#   inflating: Manzana_roja/00000000004016L.jpg
#   inflating: Manzana_roja/0003345_manzana-roja-bandeja-x-1kg.jpeg
#   inflating: Manzana_roja/0589A-4-variedades-de-manzana-roja_Simple-Blending.jpg
#   inflating: Manzana_roja/0daa535a-b946-46d0-9678-a5a704bdd9ad_lg_sq.jpg
#   inflating: Manzana_roja/10459428-manzana-roja-madura-ilustraciC3B3n-sobre-fondo-blanco.jpg
#   inflating: Manzana_roja/12119467-manzana-roja-ilustraciC3B3n.jpg
#   inflating: Manzana_roja/176563_1943069615.jpg
#   inflating: Manzana_roja/1f34e.png
#   inflating: Manzana_roja/22.png
#   inflating: Manzana_roja/2502808_00.jpg
#   inflating: Manzana_roja/2-RED-DELICIOUS-1-960x500.jpg
#   inflating: Manzana_roja/360_F_269567072_C9dMZ9CTZQQPxPxCwZt41x2pQc58QwCS.jpg
#   inflating: Manzana_roja/3715007.jpg
#   inflating: Manzana_roja/3767.png_860.png
#   inflating: Manzana_roja/500x400_manzanaroja.jpg
#   inflating: Manzana_roja/501205.jpg
# ...

# %%
#Borrar los archivo ZIP
# !rm -rf /content/Manzana_roja/Manzana_roja.zip
# !rm -rf /content/Mandarina/Mandarina.zip
# !rm -rf /content/Platano/Platano.zip
# !rm -rf /content/Fruta_NO_detectada/Fruta_NO_detectada.zip

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/Manzana_roja/Manzana_roja/ | wc -l 
# !ls /content/Mandarina/Mandarina/ | wc -l 
# !ls /content/Platano/Platano/ | wc -l 
# !ls /content/Fruta_NO_detectada/Fruta_NO_detectada/ | wc -l
# Out:
# 441
# 415
# 369
# 294

# %%
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/Fruta_NO_detectada/Fruta_NO_detectada'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %%
#Crear carpetas para hacer el set de datos

# !mkdir dataset
# !mkdir dataset/Manzana_roja
# !mkdir dataset/Mandarina
# !mkdir dataset/Platano
# !mkdir dataset/Fruta_NO_detectada
# Out:
# mkdir: cannot create directory ‘dataset’: File exists

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 419 (el num. menor de imagenes que subi)

import shutil
carpeta_fuente = '/content/Manzana_roja/Manzana_roja'
carpeta_destino = '/content/dataset/Manzana_roja'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 294:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 419 (el num. menor de imagenes que subi)

import shutil
carpeta_fuente = '/content/Mandarina/Mandarina'
carpeta_destino = '/content/dataset/Mandarina'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 294:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 419 (el num. menor de imagenes que subi)

import shutil
carpeta_fuente = '/content/Platano/Platano'
carpeta_destino = '/content/dataset/Platano'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 294:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset
#Limitar para que todos tengan la misma cantidad de imagenes
#maximo 419 (el num. menor de imagenes que subi)

import shutil
carpeta_fuente = '/content/Fruta_NO_detectada/Fruta_NO_detectada'
carpeta_destino = '/content/dataset/Fruta_NO_detectada'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 294:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/dataset/Manzana_roja/ | wc -l 
# !ls /content/dataset/Mandarina/ | wc -l 
# !ls /content/dataset/Platano/ | wc -l 
# !ls /content/dataset/Fruta_NO_detectada/ | wc -l
# Out:
# 294
# 294
# 294
# 294

# %%
#Aumento de datos con ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

#Crear el dataset generador
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
    validation_split=0.2 #20% para pruebas
)

#Generadores para sets de entrenamiento y pruebas
data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')

#Imprimir 10 imagenes del generador de entrenamiento
for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# Found 942 images belonging to 4 classes.
# Found 232 images belonging to 4 classes.

# %%
# !zip -r '/content/dataset.zip' '/content/dataset'
# Out:
#   adding: content/dataset/ (stored 0%)
#   adding: content/dataset/Manzana_roja/ (stored 0%)
#   adding: content/dataset/Manzana_roja/images9.jpg (deflated 0%)
#   adding: content/dataset/Manzana_roja/2-RED-DELICIOUS-1-960x500.jpg (deflated 1%)
#   adding: content/dataset/Manzana_roja/images263.jpg (deflated 1%)
#   adding: content/dataset/Manzana_roja/images232.jpg (deflated 4%)
#   adding: content/dataset/Manzana_roja/images369.jpg (deflated 5%)
#   adding: content/dataset/Manzana_roja/images253.jpg (deflated 2%)
#   adding: content/dataset/Manzana_roja/images376.jpg (deflated 3%)
#   adding: content/dataset/Manzana_roja/images53.jpg (deflated 7%)
#   adding: content/dataset/Manzana_roja/images125.jpg (deflated 5%)
#   adding: content/dataset/Manzana_roja/images222.jpg (deflated 6%)
#   adding: content/dataset/Manzana_roja/images181.jpg (deflated 0%)
#   adding: content/dataset/Manzana_roja/images117.jpg (deflated 1%)
# ...

# %%
from google.colab import files
files.download("/content/dataset.zip")
